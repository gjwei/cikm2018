# %%
def read_result(filepath):
    result = []
    with open(filepath, 'rt', encoding='utf-8') as f:
        for line in f:
            result.append(float(line.strip()))
    return result

# %%
import glob

# %%
files = glob.glob('../result/_*')

# %%
good_result_path  = '../result/blending/models_4_blend_b.txt'

import matplotlib.pyplot as plt
import seaborn as sns

import seaborn as sns


r1 = read_result(good_result_path)

# %%
r3 = read_result('../result/blending/models_16_blend_b.txt')

# %%
index = -1

# %%
index += 1
print(index)
r2 = read_result(files[index])

plt.scatter(r1, r3)
# Out:
# 11
